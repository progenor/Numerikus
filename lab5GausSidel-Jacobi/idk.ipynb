# %% [markdown]
# # Jacobi iteracio
#
# $$x^{k+1}=D^{-1}(L+U)x^{(k)}+D^{-1}b)$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
import matplotlib.pyplot as plt


A = np.array([[1, 2,3 ], [3, 4,3], [5, 6,3]])
b = np.array([[1], [2], [3]])
N = 1000
Eps = 1e-6
x0 = np.array([[0], [0]])

# %% [markdown]
# y = x1 // mentes
# Minden k=1..N ig
#     Minden i = 1..n
#         s=0
#         Minden l = 1..n
#             if l != i
#                 s += A[i][l] * y[l]
#             Vege if
#         Vege minden
#         x[i] = (b[i] - s) / A[i][i]
#     Vege Minden
#     if ||x-y|| < eps // x megoldas
#         break
#
#     kulomben
#         y = x
#     Vege if
# Vege Minden
